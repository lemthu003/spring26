# %% [markdown]
# Using Jupyter Notebook + Google Colab extension for easy compute resources.

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda
